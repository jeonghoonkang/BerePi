# %%
import os

print (os.getcwd())
# Out:
# /Users/tinyos/devel/BerePi/apps/data_science

# %%
print (os.listdir())
# Out:
# ['jupyter_test.py', 'dask', 'readme.md', 'sample.png', '.ipynb_checkpoints', 'jupyter_test.ipynb']

# %%
from IPython.display import Image, display, clear_output


from datetime import datetime

while (True):
    key_in_val = input(" 키보드입력 ==> 새로고침, X 입력시 종료  ...")
    clear_output(wait=True)
    now = datetime.now()

    print ("TIME =>", now)

    if key_in_val != 'x' :
        display(Image(filename='sample.png'))
        continue
        
    print ("OUT...")
    break
# Out:
# TIME => 2022-11-01 01:34:40.826855
